# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sn
import math

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, roc_auc_score

# %%
# df = pd.read_csv('data/hello.csv')
df = pd.read_csv('微信小程序低活跃群体.csv',encoding = 'gbk',low_memory = False)

# %%
df['is_unpay'] = df['is_pay'].apply(lambda x: 1 if x==0 else 0)

# %%
df.shape
df = df[:6000]

# %%
df.shape
df_csv = df[:20000]

# %%
df_csv['is_pay'].value

# %%
df.columns
# Out:
# Index(['is_pay', 'p_id', 'o_id', 'returncode', 'cur_start_distance',
#        'valid_start_dest_distance', 'caller_fast_car_count_call',
#        'caller_count_bad', 'caller_p_complete_order_rate',
#        'caller_sum_invoice_value_per_complete',
#        'amt_paid_finish_orders_14_d_fast', 'cnt_pay_succ_orders_14_d_fast',
#        'amt_paid_finish_orders_14_d_gulf', 'cnt_pay_succ_orders_14_d_gulf',
#        'cnt_pay_succ_orders_30_d_fast', 'amt_paid_finish_orders_30_d_fast',
#        'total_amt_paid_finish_orders_fast',
#        'total_amt_paid_finish_orders_gulf', 'pay_success_total_fee',
#        'avg_actual_amt_90_days', 'max_actual_amt_90_days',
#        'count_complete_pay_90_days_orders', 'complete_orders_one_month',
#        'count_complete_pay_90_days_channel', 'complete_gmv_one_month',
#        'ali_risk_score', 'is_zmxy_normal_sign', 'nopass_huazhi_status',
#        'pay_order_create_time_diff_day', 'rain_score', 'sum_gmv_3_months',
#        'valid_es_pre_total_fee', 'tx_auth_status', 'anycar_require_len',
#        'count_ip_new_od', 'is_hit_wx_black', 'wx_pid_cnt_3day', 'scene_l1',
#        'hxz_bad_order_to_date_days', 'is_unpay'],
#       dtype='object')

# %%
# 正负样本
df['is_unpay'].value_counts()
#df['is_unpay'].value_counts()/df['is_unpay'].count()
# Out:
# 0    4785
# 1    1215
# Name: is_unpay, dtype: int64

# %%
feats = [feat for feat in df.columns if feat not in ['p_id','returncode','o_id','is_pay']]
df2 = df[feats]

# %% [markdown]
# ## 决策树挖掘规则

# %%
#!pip install toad --trusted-host didiyun.sys.xiaojukeji.com
#!pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pydotplus

# %%
import toad
import pandas as pd
import numpy as np
import pydotplus
from IPython.display import Image
from six import StringIO
import os
from sklearn import tree

# %%
class auto_tree(object):
   
    def __init__(self,datasets,ex_lis,dep='bad_ind',min_samples=0.05,min_samples_leaf=200,min_samples_split=20,max_depth=4,is_bin=True):

        '''
        datasets:数据集 dataframe格式
        ex_lis：不参与建模的特征，如id，时间切片等。 list格式
        min_samples：分箱时最小箱的样本占总比 numeric格式
        max_depth：决策树最大深度 numeric格式
        min_samples_leaf：决策树子节点最小样本个数 numeric格式
        min_samples_split：决策树划分前，父节点最小样本个数 numeric格式
        is_bin：是否进行卡方分箱 bool格式（True/False）
        '''
        self.datasets = datasets
        self.ex_lis = ex_lis
        self.dep = dep
        self.max_depth = max_depth
        self.min_samples = min_samples
        self.min_samples_leaf = min_samples_leaf
        self.min_samples_split = min_samples_split
        self.is_bin = is_bin

        self.bins = 0
        
    def fit_plot(self):
        os.environ["PATH"] += os.pathsep + 'graph'
        dtree = tree.DecisionTreeRegressor(max_depth=self.max_depth,
                                           min_samples_leaf=self.min_samples_leaf, 
                                           min_samples_split=self.min_samples_split)
        
        x = self.datasets.drop(self.ex_lis,axis=1)
        y = self.datasets[self.dep]
        
        if self.is_bin:
            #分箱
            combiner = toad.transform.Combiner()
            combiner.fit(x,y,method='chi',min_samples = self.min_samples)

            x_bin= combiner.transform(x)
            self.bins = combiner.export()        
        else:
            x_bin = x.copy()
            
        dtree = dtree.fit(x_bin,y) 
        
        df_bin = x_bin.copy()
        
        df_bin[self.dep] = y
        
        dot_data = StringIO()
        tree.export_graphviz(dtree, out_file=dot_data,
                                 feature_names=x_bin.columns,
                                 class_names=[self.dep],
                                 filled=True, rounded=True,
                                 special_characters=True)
        graph = pydotplus.graph_from_dot_data(dot_data.getvalue()) 

            
        return df_bin,self.bins,combiner,graph.create_png(),dtree

# %%
df_bin.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-28802c37cf78> in <module>
# ----> 1 df_bin.columns
#
# NameError: name 'df_bin' is not defined

# %% [markdown]
# ## 评估

# %%
#指定不参与建模的变量，包含标签bad_ind
ex_lis = ['is_unpay']
          #,'last_unpay_days','count_pay_120d','count_pay_90d','count_pay_28d']
#调用决策树函数
df_bin,bins,combiner,graph,dtree = auto_tree(datasets = df2,ex_lis = ex_lis,
                                       dep = 'is_unpay',min_samples=0.01,
                                       min_samples_leaf=100,max_depth=6).fit_plot()
#展示图像
Image(graph)

# %%
#-------------------------
# 功能：输出Python函数代码
#
#-------------------------
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    print("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)
    
#tree_to_code(dtree, df_bin.columns)

# %%
#-------------------------
# 功能：输出未付率头部规则
#
#-------------------------
def tree_to_rule(tree, feature_names, bins):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    
    res = {}
    temp = []
    def recurse(node, depth):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = bins[feature_name[node]][math.floor(tree_.threshold[node])]
            temp.append("{} <= {}".format(name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            temp.pop()
            temp.append("{} > {}".format(name, threshold))
            recurse(tree_.children_right[node], depth + 1)
            temp.pop()
        else:
            rule = ' and '.join(temp)
            unpay_rate = tree_.value[node][0][0]
            o_cnt = tree_.n_node_samples[node]
            res[rule] = (unpay_rate, o_cnt)
            
    recurse(0, 1)
    return res

res = tree_to_rule(dtree, df_bin.columns, bins)
sorted(res.items(),key=lambda x:x[1][0],reverse=True)
# Out:
# [('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance > 7163 and rain_score <= -1.0 and anycar_require_len > 711',
#   (0.5631067961165048, 103)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance > 7163 and rain_score > -1.0 and nopass_huazhi_status > 1.0 and caller_count_bad > 7.0',
#   (0.48333333333333334, 120)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance > 7163 and rain_score <= -1.0 and anycar_require_len <= 711',
#   (0.46616541353383456, 133)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel <= 1.0',
#   (0.41007194244604317, 139)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee > 32.44 and caller_sum_invoice_value_per_complete <= 0.06451613',
#   (0.387434554973822, 191)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance > 7163 and rain_score > -1.0 and nopass_huazhi_status <= 1.0 and caller_sum_invoice_value_per_complete <= 0.06451613',
#   (0.35526315789473684, 152)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score <= 3.0 and valid_start_dest_distance > 3848 and caller_sum_invoice_value_per_complete <= 0.06451613',
#   (0.3351063829787234, 188)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score > 3.0 and count_complete_pay_90_days_orders <= 2.0 and pay_order_create_time_diff_day > 3.0',
#   (0.32786885245901637, 122)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score <= -1.0 and caller_fast_car_count_call > 20.0 and valid_es_pre_total_fee > 13.5',
#   (0.32558139534883723, 129)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance > 7163 and rain_score > -1.0 and nopass_huazhi_status > 1.0 and caller_count_bad <= 7.0',
#   (0.304635761589404, 151)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day > 13.0 and anycar_require_len > 1231 and caller_fast_car_count_call <= 96.0',
#   (0.29245283018867924, 106)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee > 32.44 and caller_sum_invoice_value_per_complete > 0.06451613 and nopass_huazhi_status > 1.0',
#   (0.27564102564102566, 156)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance > 7163 and rain_score > -1.0 and nopass_huazhi_status <= 1.0 and caller_sum_invoice_value_per_complete > 0.06451613 and caller_count_bad > 3.0',
#   (0.2617801047120419, 191)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score <= 3.0 and valid_start_dest_distance <= 3848 and tx_auth_status <= 2000.0',
#   (0.24481327800829875, 241)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score <= 3.0 and valid_start_dest_distance > 3848 and caller_sum_invoice_value_per_complete > 0.06451613',
#   (0.23333333333333334, 180)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day <= 13.0 and nopass_huazhi_status > 2.0 and cur_start_distance <= 37.0',
#   (0.2152777777777778, 144)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score > 3.0 and count_complete_pay_90_days_orders > 2.0 and max_actual_amt_90_days > 13.0',
#   (0.1729490022172949, 451)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance > 7163 and rain_score > -1.0 and nopass_huazhi_status <= 1.0 and caller_sum_invoice_value_per_complete > 0.06451613 and caller_count_bad <= 3.0',
#   (0.17037037037037037, 135)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day > 13.0 and anycar_require_len <= 1231 and sum_gmv_3_months > 25.37',
#   (0.16352201257861634, 159)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score <= -1.0 and caller_fast_car_count_call > 20.0 and valid_es_pre_total_fee <= 13.5',
#   (0.1619718309859155, 142)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score > 3.0 and count_complete_pay_90_days_orders <= 2.0 and pay_order_create_time_diff_day <= 3.0',
#   (0.1557377049180328, 122)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score <= 3.0 and valid_start_dest_distance <= 3848 and tx_auth_status > 2000.0',
#   (0.15025906735751296, 193)),
#  ("count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day <= 13.0 and nopass_huazhi_status <= 2.0 and scene_l1 > ['其他']",
#   (0.14184397163120568, 141)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day > 13.0 and anycar_require_len > 1231 and caller_fast_car_count_call > 96.0',
#   (0.1391304347826087, 115)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee > 32.44 and caller_sum_invoice_value_per_complete > 0.06451613 and nopass_huazhi_status <= 1.0',
#   (0.125, 192)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score <= -1.0 and caller_fast_car_count_call <= 20.0',
#   (0.12422360248447205, 161)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day <= 13.0 and nopass_huazhi_status > 2.0 and cur_start_distance > 37.0',
#   (0.09433962264150944, 159)),
#  ('count_complete_pay_90_days_orders <= 5.0 and valid_start_dest_distance <= 7163 and count_complete_pay_90_days_channel > 1.0 and rain_score > 3.0 and count_complete_pay_90_days_orders > 2.0 and max_actual_amt_90_days <= 13.0',
#   (0.08636363636363636, 220)),
#  ('count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day > 13.0 and anycar_require_len <= 1231 and sum_gmv_3_months <= 25.37',
#   (0.08333333333333333, 156)),
#  ("count_complete_pay_90_days_orders > 5.0 and valid_es_pre_total_fee <= 32.44 and rain_score > -1.0 and pay_order_create_time_diff_day <= 13.0 and nopass_huazhi_status <= 2.0 and scene_l1 <= ['其他']",
#   (0.06622516556291391, 1208))]

# %%
#查看数据集中单个变量的分箱结果
print(set(df_bin['cur_start_distance']))
#查看单个变量的分箱详情
print(bins['cur_start_distance'])
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}
# [6.0, 24.0, 27.0, 37.0, 59.0, 68.0, 248.0]

# %% [markdown]
# ## 评估策略

# %%
dt_cnt = len(df['dt'].unique())
print(df['dt'].value_counts())
print(dt_cnt)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-f0cceb20c884> in <module>
# ----> 1 dt_cnt = len(df['dt'].unique())
#       2 print(df['dt'].value_counts())
#       3 print(dt_cnt)
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'dt'

# %%
# 策略3 专快有未付
df4 = df[
    (df['effectstrategyid'].isna())&
    (df['valid_es_pre_total_fee']>=0)
]
df4['is_unpay'].agg(['sum','mean','count'])
# Out:
# sum        87.000000
# mean        0.062861
# count    1384.000000
# Name: is_unpay, dtype: float64

# %%
print('每日命中订单数: ', df4.shape[0]/dt_cnt)
print('每日未支付订单数: ', df4['is_unpay'].sum()/dt_cnt)
print('每日未支付金额: ', (df4['is_unpay']*df4['gmv_total_fee']).sum()/dt_cnt)
print('每日影响GMV: ', df4['gmv_total_fee'].sum()/dt_cnt)
print('订单未付率: ', df4['is_unpay'].sum()/df4.shape[0])
print('金额未支付率: ', (df4['is_unpay']*df4['gmv_total_fee']).sum()/df4['gmv_total_fee'].sum())
# Out:
# 每日命中订单数:  138.4
# 每日未支付订单数:  8.7
# 每日未支付金额:  670.96
# 每日影响GMV:  3572.3599999999997
# 订单未付率:  0.06286127167630058
# 金额未支付率:  0.18781981659183286

# %%
# df = pd.read_csv('data/hello.csv')
df1 = pd.read_csv('微信小程序低活跃群体.csv',encoding = 'gbk',low_memory = False)

# %%
df1.shape
df_csv = df1[:200000]

# %%
df_csv['is_pay'].value_counts()
# Out:
# 1    111409
# 0     88591
# Name: is_pay, dtype: int64

# %%
df_csv

# %%
df_csv.to_csv('')
